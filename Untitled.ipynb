# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %pylab inline --no-import-all
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
x = np.arange(-3, 3, .1)
y = np.sin(x)
plt.plot(x, y)

# %%
x = np.random.randn(30)
y = np.sin(x) + np.random.randn(30)
plt.plot(x, y, "o")  # "o"は小さい円(circle marker)

# %%
plt.hist(np.random.randn(1000))
# Out:
# (array([   1.,    1.,   22.,   53.,  165.,  228.,  278.,  136.,   82.,   34.]),
#  array([-4.02854421, -3.36970752, -2.71087084, -2.05203415, -1.39319746,
#         -0.73436077, -0.07552409,  0.5833126 ,  1.24214929,  1.90098598,
#          2.55982267]),
#  <a list of 10 Patch objects>)

# %%
plt.imshow(np.random.randn(100, 100))

# %%
x = np.arange(0, 10, 0.1)
y = np.exp(x)
plt.plot(x, y)
plt.title("exponential function: $ y = e^x $")
plt.ylim(0, 5000)  # yを0-5000の範囲に限定
# Out:
# (0, 5000)

# %%
xmin, xmax = -np.pi, np.pi
x = np.arange(xmin, xmax, 0.1)
y_sin = np.sin(x)
y_cos = np.cos(x)
plt.plot(x, y_sin)
plt.plot(x, y_cos)
plt.hlines([-1, 1], xmin, xmax, linestyles="dashed")  # y=-1, 1に破線を描画
plt.title(r"$\sin(x)$ and $\cos(x)$")
plt.xlim(xmin, xmax)
plt.ylim(-1.3, 1.3)
# Out:
# (-1.3, 1.3)
